# %% [markdown]
# # 04 - Model Debugging
# Sanity-check model forward pass and output tensor shapes.

# %%
import torch
from src.models.gnn_model import LocalizationGNN
model = LocalizationGNN(input_dim=16)
model(torch.randn(8, 16)).shape
