# %% [markdown]
# # 03 - Graph Inspection
# Inspect graph topology statistics (degree, components, density).

# %%
import networkx as nx
# TODO: load graph artifact from ../data/processed/graphs
g = nx.Graph()
g.number_of_nodes(), g.number_of_edges()
